# %% [markdown]
# # APIs - Gathering Data Using Requests

# %% [markdown]
# ## The Many Use Cases For Application Programming Interfaces
#
# APIs can be used for many things - much more than just retrieving information. Twilio has an API that allows you to write a script to send text messages to people. GitHub has an API for creating new repositories. Many services have APIs allowing computers to automate tasks that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database, or getting a list of garbage collection times for a municipality.

# %% [markdown]
# ## Limitations of APIs
#
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.
#
# * **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information you might want through their API
#
# * **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.
#
# What else is good to know? **Every API is different!** There are some standards out there in terms of documentation and usage... but it's like the wild west - rapid expansion with few rules.
#
# With all that out of the way - Let's take a look at the `requests` library and its uses.

# %% [markdown]
# ### "Requests is the only Non-GMO HTTP library for Python, safe for human consumption."
#
# > "Requests allows you to send organic, grass-fed HTTP/1.1 requests, without the need for manual labor."
#
# Straight from the `requests` [documentation](https://pypi.org/project/requests/)

# %% [markdown]
# ### Types of Requests
#
# We will mostly use GET requests in order to get data, but there are other options.
#
# ![CRUD image from IntelliPaat](https://intellipaat.com/mediaFiles/2015/08/MongoDB-CRUD-operations.jpg)
#
# That's right - CRUD summarizes the kinds of requests you can make with most APIs.
#
# Let's say you are looking at an API for a car rental company like Hertz or Zipcar - the following different requests could generate these different responses:
#
# | Request               | Result                               | In CRUD Terms |
# | --------------------- | ------------------------------------ | ------------- |
# | GET /stores/          | User sees the list of stores         | Read          |
# | GET /rentals/         | User sees the history of car rentals | Read          |
# | POST /rentals/        | User rents a car                     | Create        |
# | PUT /rentals/{id}/    | User changes destination store       | Update        |
# | DELETE /rentals/{id}/ | User cancels the active car rental   | Delete        |

# %% [markdown]
# ### Let's get started!

# %%
import requests

# %%
# Don't already have the library? Uncomment the below code and install it locally
#!pip install requests

# %%
# Create a GET request, then check the type of object

r = requests.get('https://api.github.com/events') 
type(r)
# Out:
# requests.models.Response

# %%
# So what does this look like?
r.text
# Out:
# '[{"id":"21308624281","type":"PushEvent","actor":{"id":71234962,"login":"JUANHercs","display_login":"JUANHercs","gravatar_id":"","url":"https://api.github.com/users/JUANHercs","avatar_url":"https://avatars.githubusercontent.com/u/71234962?"},"repo":{"id":481831349,"name":"JUANHercs/holbertonschool-web_front_end","url":"https://api.github.com/repos/JUANHercs/holbertonschool-web_front_end"},"payload":{"push_id":9636402846,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"976d5606320d71cfe66b9058310b195149a90708","before":"db5ba2e5db00b32945007a36555e933a5e08f8a7","commits":[{"sha":"976d5606320d71cfe66b9058310b195149a90708","author":{"email":"juan.hercs@gmail.com","name":"JUANHercs"},"message":"Meta_description","distinct":true,"url":"https://api.github.com/repos/JUANHercs/holbertonschool-web_front_end/commits/976d5606320d71cfe66b9058310b195149a90708"}]},"public":true,"created_at":"2022-04-15T15:24:05Z"},{"id":"21308624267","type":"PullRequestEvent","actor":{"id":1649973,"login":"juanhurtado10","display_login":"juanhurtado10","gravatar_id":"","url":"https://api.github.com/users/juanhurtado10","avatar_url":"https://avatars.githubusercontent.com/u/1649973?"},"repo":{"id":394467538,"name":"kommitters/stellar_sdk","url":"https://api.github.com/repos/kommitters/stellar_sdk"},"payload":{"action":"closed","number":139,"pull_request":{"url":"https://api.github.com/repos/kommitters/stellar_sdk/pulls/139","id":910137372,"node_id":"PR_kwDOF4MY0s42P5gc","html_url":"https://github.com/kommitters/stellar_sdk/pull/139","diff_url":"https://github.com/kommitters/stellar_sdk/pull/139.diff","patch_url":"https://github.com/kommitters/stellar_sdk/pull/139.patch","issue_url":"https://api.github.com/repos/kommitters/stellar_sdk/issues/139","number":139,"state":"closed","locked":false,"title":"Error management for TxBuild module","user":{"login":"juanhurtado10","id":1649973,"node_id":"MDQ6VXNlcjE2NDk5NzM=","avatar_url":"https://avatars.githubusercontent.com/u/1649973?v=4","gravatar_id":"","url":"https://api.github.com/users/juanhurtado10","html_url":"https://github.com/juanhurtado10","followers_url":"https://api.github.com/users/juanhurtado10/followers","following_url":"https://api.github.com/users/juanhurtado10/following{/other_user}","gists_url":"https://api.github.com/users/juanhurtado10/gists{/gist_id}","starred_url":"https://api.github.com/users/juanhurtado10/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/juanhurtado10/subscriptions","organizations_url":"https://api.github.com/users/juanhurtado10/orgs","repos_url":"https://api.github.com/users/juanhurtado10/repos","events_url":"https://api.github.com/users/juanhurtado10/events{/privacy}","received_events_url":"https://api.github.com/users/juanhurtado10/received_events","type":"User","site_admin":false},"body":"Closes #137 ","created_at":"2022-04-14T16:29:06Z","updated_at":"2022-04-15T15:24:05Z","closed_at":"2022-04-15T15:24:05Z","merged_at":"2022-04-15T15:24:05Z","merge_commit_sha":"c55208e10fc9cb1b67a8c6783329c56fbf021308","assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"draft":false,"commits_url":"https://api.github.com/repos/kommitters/stellar_sdk/pulls/139/commits","review_comments_url":"https://api.github.com/repos/kommitters/stellar_sdk/pulls/139/comments","review_comment_url":"https://api.github.com/repos/kommitters/stellar_sdk/pulls/comments{/number}","comments_url":"https://api.github.com/repos/kommitters/stellar_sdk/issues/139/comments","statuses_url":"https://api.github.com/repos/kommitters/stellar_sdk/statuses/30b33c120cd7c7093216da5e70d0ff27e4662bd8","head":{"label":"kommitters:137-tx-build-error-management","ref":"137-tx-build-error-management","sha":"30b33c120cd7c7093216da5e70d0ff27e4662bd8","user":{"login":"kommitters","id":7662046,"node_id":"MDEyOk9yZ2FuaXphdGlvbjc2NjIwNDY=","avatar_url":"https://avatars.githubusercontent.com/u/7662046?v=4","gravatar_id":"","url":"https://api.github.com/us ...

# %% [markdown]
# ![Oh good heavens gif, from gfycat](https://thumbs.gfycat.com/ColdAmbitiousDogwoodtwigborer-size_restricted.gif)

# %% [markdown]
# Obviously you're never going to just scan that quickly for any data you need, we need to wrangle that response to make it usable.
#
# But first, let's look at some of the other attributes of `requests.models.Response` objects.
#
# We can check out all of the attributes [here](https://2.python-requests.org//en/v0.10.6/api/) in the documentation.

# %%
# Another attribute, what does this show us?
r.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Fri, 15 Apr 2022 15:29:05 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"42fbfb5adc70b314ab55237f8fe98792c3067588f643a53886070f4adec50fc5"', 'Last-Modified': 'Fri, 15 Apr 2022 15:24:05 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '58', 'X-RateLimit-Reset': '1650039731', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '2', 'Accept-Ranges': 'bytes', 'Content-Length': '27087', 'X-GitHub-Request-Id': 'C1DD:272D:B9E2EE:1DFF9B5:62598F51'}

# %% [markdown]
# ### Checking out the status of your request

# %%
# Another attribute
r.status_code
# Out:
# 200

# %% [markdown]
# ### [Types of status codes](https://http.cat/)
#
# 1xx - Informational responses
#
# 2xx - Success
# - 200 OK
# - 201 Created
# - 204 No Content
#
# 3xx - Redirection
#
# - 301 Moved Permanently (permanent URL redirection)
# - 304 Not Modified (A conditional GET or HEAD request has been received and would have resulted in a 200 OK response if it were not for the fact that the condition evaluated to false.)
#
# 4xx - Client errors
#
# - 400 Bad Request
# - 401 Unauthorized
# - 403 Forbidden
# - 404 Not Found
#
# 5xx - Server errors
#
# - 500 Internal Server Error

# %%
# Get status code for a "broken" link

r_broken = requests.get('https://api.github.com/fake-ending')
r_broken.status_code
# Out:
# 404

# %% [markdown]
# #### A note on errors and exceptions with the Requests library
#
# There are a number of exceptions and error codes you need to be familiar with when using the Requests library in Python.
#
# - The Requests library will raise a ConnectionError exception if there is a network problem like a DNS failure, or refused connection
# - These are rare, but with invalid HTTP responses, Requests will also raise an HTTPError exception
# - A Timeout exception will be raised if a request times out
# - If and when a request exceeds the preconfigured number of maximum redirections, then a TooManyRedirects exception will be raised

# %% [markdown]
# Can also explictly ask for the returned format to be json as a method.

# %%
# Going back to our working request - how does this look, compared to text?
r.json()
# Out:
# [{'id': '21308624281',
#   'type': 'PushEvent',
#   'actor': {'id': 71234962,
#    'login': 'JUANHercs',
#    'display_login': 'JUANHercs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JUANHercs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71234962?'},
#   'repo': {'id': 481831349,
#    'name': 'JUANHercs/holbertonschool-web_front_end',
#    'url': 'https://api.github.com/repos/JUANHercs/holbertonschool-web_front_end'},
#   'payload': {'push_id': 9636402846,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '976d5606320d71cfe66b9058310b195149a90708',
#    'before': 'db5ba2e5db00b32945007a36555e933a5e08f8a7',
#    'commits': [{'sha': '976d5606320d71cfe66b9058310b195149a90708',
#      'author': {'email': 'juan.hercs@gmail.com', 'name': 'JUANHercs'},
#      'message': 'Meta_description',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/JUANHercs/holbertonschool-web_front_end/commits/976d5606320d71cfe66b9058310b195149a90708'}]},
#   'public': True,
#   'created_at': '2022-04-15T15:24:05Z'},
#  {'id': '21308624267',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 1649973,
#    'login': 'juanhurtado10',
#    'display_login': 'juanhurtado10',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/juanhurtado10',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1649973?'},
#   'repo': {'id': 394467538,
#    'name': 'kommitters/stellar_sdk',
#    'url': 'https://api.github.com/repos/kommitters/stellar_sdk'},
#   'payload': {'action': 'closed',
#    'number': 139,
#    'pull_request': {'url': 'https://api.github.com/repos/kommitters/stellar_sdk/pulls/139',
#     'id': 910137372,
#     'node_id': 'PR_kwDOF4MY0s42P5gc',
#     'html_url': 'https://github.com/kommitters/stellar_sdk/pull/139',
#     'diff_url': 'https://github.com/kommitters/stellar_sdk/pull/139.diff',
#     'patch_url': 'https://github.com/kommitters/stellar_sdk/pull/139.patch',
#     'issue_url': 'https://api.github.com/repos/kommitters/stellar_sdk/issues/139',
#     'number': 139,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Error management for TxBuild module',
#     'user': {'login': 'juanhurtado10',
#      'id': 1649973,
#      'node_id': 'MDQ6VXNlcjE2NDk5NzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1649973?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/juanhurtado10',
#      'html_url': 'https://github.com/juanhurtado10',
#      'followers_url': 'https://api.github.com/users/juanhurtado10/followers',
#      'following_url': 'https://api.github.com/users/juanhurtado10/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/juanhurtado10/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/juanhurtado10/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/juanhurtado10/subscriptions',
#      'organizations_url': 'https://api.github.com/users/juanhurtado10/orgs',
#      'repos_url': 'https://api.github.com/users/juanhurtado10/repos',
#      'events_url': 'https://api.github.com/users/juanhurtado10/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/juanhurtado10/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Closes #137 ',
#     'created_at': '2022-04-14T16:29:06Z',
#     'updated_at': '2022-04-15T15:24:05Z',
#     'closed_at': '2022-04-15T15:24:05Z',
#     'merged_at': '2022-04-15T15:24:05Z',
#     'merge_commit_sha': 'c55208e10fc9cb1b67a8c6783329c56fbf021308',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/kommitters/stellar_sdk/pulls/139/commits',
#     'review_comments_url': 'https://api.github.com/repos/kommitters/stellar_sdk/pulls/139/comments',
#     'review_comment_url': 'https://api.github.com/repos/kommitters/stellar_sdk/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/kommitters/stellar_sdk/issues/139/comments',
#     'statuses_url': 'https://api.github.com/repos/kommitters/stellar_sdk/statuses/30b33c120cd7c7093216da5e70d0ff27e4662bd8',
#     'head': {'label': 'kommitters:137-tx-build-error-management',
#      'ref': '137-tx-build-error-management',
#      'sha': '30b33c120cd7c7093216da5e70d0ff27e4662bd8',
#      'user': {'login': 'kommitters',
#       'id': 7662046,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc2NjIwNDY=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/7662046?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kommitters',
#       'html_url': 'https://github.com/kommitters',
#       'followers_url': 'https://api.github.com/users/kommitters/followers',
#       'following_url': 'https://api.github.com/users/kommitters/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kommitters/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kommitters/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kommitters/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kommitters/orgs',
#       'repos_url': 'https://api.github.com/users/kommitters/repos',
#       'events_url': 'https://api.github.com/users/kommitters/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kommitters/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 394467538,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ0Njc1Mzg=',
#       'name': 'stellar_sdk',
#       'full_name': 'kommitters/stellar_sdk',
#       'private': False,
#       'owner': {'login': 'kommitters',
#        'id': 7662046,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc2NjIwNDY=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/7662046?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/kommitters',
#        'html_url': 'https://github.com/kommitters',
#        'followers_url': 'https://api.github.com/users/kommitters/followers',
#        'following_url': 'https://api.github.com/users/kommitters/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/kommitters/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/kommitters/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/kommitters/subscriptions',
#        'organizations_url': 'https://api.github.com/users/kommitters/orgs',
#        'repos_url': 'https://api.github.com/users/kommitters/repos',
#        'events_url': 'https://api.github.com/users/kommitters/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/kommitters/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/kommitters/stellar_sdk',
#       'description': 'Elixir Library to build Stellar transactions, as well as to interact with the REST endpoints of the Horizon server.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/kommitters/stellar_sdk',
#       'forks_url': 'https://api.github.com/repos/kommitters/stellar_sdk/forks',
#       'keys_url': 'https://api.github.com/repos/kommitters/stellar_sdk/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/kommitters/stellar_sdk/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/kommitters/stellar_sdk/teams',
#       'hooks_url': 'https://api.github.com/repos/kommitters/stellar_sdk/hooks',
#       'issue_events_url': 'https://api.github.com/repos/kommitters/stellar_sdk/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/kommitters/stellar_sdk/events',
#       'assignees_url': 'https://api.github.com/repos/kommitters/stellar_sdk/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/kommitters/stellar_sdk/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/kommitters/stellar_sdk/tags',
#       'blobs_url': 'https://api.github.com/repos/kommitters/stellar_sdk/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/kommitters/stellar_sdk/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/kommitters/stellar_sdk/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/kommitters/stellar_sdk/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/kommitters/stellar_sdk/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/kommitters/stellar_sdk/languages',
#       'stargazers_url': 'https://api.github.com/repos/kommitters/stellar_sdk/stargazers',
#       'contributors_url': 'https://api.github.com/repos/kommitters/stellar_sdk/contributors',
#       'subscribers_url': 'https://api.github.com/repos/kommitters/stellar_sdk/subscribers',
#       'subscription_url': 'https://api.github.com/repos/kommitters/stellar_sdk/subscription',
#       'commits_url': 'https://api.github.com/repos/kommitters/stellar_sdk/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/kommitters/stellar_sdk/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/kommitters/stellar_sdk/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/kommitters/stellar_sdk/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/kommitters/stellar_sdk/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/kommitters/stellar_sdk/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/kommitters/stellar_sdk/merges',
#       'archive_url': 'https://api.github.com/repos/kommitters/stellar_sdk/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/kommitters/stellar_sdk/downloads',
#       'issues_url': 'https://api.github.com/repos/kommitters/stellar_sdk/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/kommitters/stellar_sdk/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/kommitters/stellar_sdk/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/kommitters/stellar_sdk/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/kommitters/stellar_sdk/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/kommitters/stellar_sdk/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/kommitters/stellar_sdk/deployments',
#       'created_at': '2021-08-09T23:27:46Z',
#       'updated_at': '2022-03-22T19:16:55Z',
#       'pushed_at': '2022-04-15T15:24:05Z',
#       'git_url': 'git://github.com/kommitters/stellar_sdk.git',
#       'ssh_url': 'git@github.com:kommitters/stellar_sdk.git',
#       'clone_url': 'https://github.com/kommitters/stellar_sdk.git',
#       'svn_url': 'https://github.com/kommitters/stellar_sdk',
#       'homepage': 'https://hex.pm/packages/stellar_sdk',
#       'size': 395,
#       'stargazers_count': 3,
#       'watchers_count': 3,
#       'language': 'Elixir',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 2,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 12,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['blockchain',
#        'crypto',
#        'elixir',
#        'elixir-lang',
#        'sdk',
#        'stellar',
#        'stellar-network'],
#       'visibility': 'public',
#       'forks': 2,
#       'open_issues': 12,
#       'watchers': 3,
#       'default_branch': 'main'}},
#     'base': {'label': 'kommitters:v0.6',
#      'ref': 'v0.6',
#      'sha': '002b6809f55fd66d947e51fe23daf372a5c93ef9',
#      'user': {'login': 'kommitters',
#       'id': 7662046,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc2NjIwNDY=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/7662046?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/kommitters',
#       'html_url': 'https://github.com/kommitters',
#       'followers_url': 'https://api.github.com/users/kommitters/followers',
#       'following_url': 'https://api.github.com/users/kommitters/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/kommitters/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/kommitters/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/kommitters/subscriptions',
#       'organizations_url': 'https://api.github.com/users/kommitters/orgs',
#       'repos_url': 'https://api.github.com/users/kommitters/repos',
#       'events_url': 'https://api.github.com/users/kommitters/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/kommitters/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 394467538,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ0Njc1Mzg=',
#       'name': 'stellar_sdk',
#       'full_name': 'kommitters/stellar_sdk',
#       'private': False,
#       'owner': {'login': 'kommitters',
#        'id': 7662046,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc2NjIwNDY=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/7662046?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/kommitters',
#        'html_url': 'https://github.com/kommitters',
#        'followers_url': 'https://api.github.com/users/kommitters/followers',
#        'following_url': 'https://api.github.com/users/kommitters/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/kommitters/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/kommitters/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/kommitters/subscriptions',
#        'organizations_url': 'https://api.github.com/users/kommitters/orgs',
#        'repos_url': 'https://api.github.com/users/kommitters/repos',
#        'events_url': 'https://api.github.com/users/kommitters/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/kommitters/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/kommitters/stellar_sdk',
#       'description': 'Elixir Library to build Stellar transactions, as well as to interact with the REST endpoints of the Horizon server.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/kommitters/stellar_sdk',
#       'forks_url': 'https://api.github.com/repos/kommitters/stellar_sdk/forks',
#       'keys_url': 'https://api.github.com/repos/kommitters/stellar_sdk/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/kommitters/stellar_sdk/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/kommitters/stellar_sdk/teams',
#       'hooks_url': 'https://api.github.com/repos/kommitters/stellar_sdk/hooks',
#       'issue_events_url': 'https://api.github.com/repos/kommitters/stellar_sdk/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/kommitters/stellar_sdk/events',
#       'assignees_url': 'https://api.github.com/repos/kommitters/stellar_sdk/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/kommitters/stellar_sdk/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/kommitters/stellar_sdk/tags',
#       'blobs_url': 'https://api.github.com/repos/kommitters/stellar_sdk/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/kommitters/stellar_sdk/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/kommitters/stellar_sdk/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/kommitters/stellar_sdk/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/kommitters/stellar_sdk/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/kommitters/stellar_sdk/languages',
#       'stargazers_url': 'https://api.github.com/repos/kommitters/stellar_sdk/stargazers',
#       'contributors_url': 'https://api.github.com/repos/kommitters/stellar_sdk/contributors',
#       'subscribers_url': 'https://api.github.com/repos/kommitters/stellar_sdk/subscribers',
#       'subscription_url': 'https://api.github.com/repos/kommitters/stellar_sdk/subscription',
#       'commits_url': 'https://api.github.com/repos/kommitters/stellar_sdk/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/kommitters/stellar_sdk/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/kommitters/stellar_sdk/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/kommitters/stellar_sdk/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/kommitters/stellar_sdk/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/kommitters/stellar_sdk/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/kommitters/stellar_sdk/merges',
#       'archive_url': 'https://api.github.com/repos/kommitters/stellar_sdk/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/kommitters/stellar_sdk/downloads',
#       'issues_url': 'https://api.github.com/repos/kommitters/stellar_sdk/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/kommitters/stellar_sdk/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/kommitters/stellar_sdk/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/kommitters/stellar_sdk/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/kommitters/stellar_sdk/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/kommitters/stellar_sdk/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/kommitters/stellar_sdk/deployments',
#       'created_at': '2021-08-09T23:27:46Z',
#       'updated_at': '2022-03-22T19:16:55Z',
#       'pushed_at': '2022-04-15T15:24:05Z',
#       'git_url': 'git://github.com/kommitters/stellar_sdk.git',
#       'ssh_url': 'git@github.com:kommitters/stellar_sdk.git',
#       'clone_url': 'https://github.com/kommitters/stellar_sdk.git',
#       'svn_url': 'https://github.com/kommitters/stellar_sdk',
#       'homepage': 'https://hex.pm/packages/stellar_sdk',
#       'size': 395,
#       'stargazers_count': 3,
#       'watchers_count': 3,
#       'language': 'Elixir',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 2,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 12,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['blockchain',
#        'crypto',
#        'elixir',
#        'elixir-lang',
#        'sdk',
#        'stellar',
#        'stellar-network'],
#       'visibility': 'public',
#       'forks': 2,
#       'open_issues': 12,
#       'watchers': 3,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/kommitters/stellar_sdk/pulls/139'},
#      'html': {'href': 'https://github.com/kommitters/stellar_sdk/pull/139'},
#      'issue': {'href': 'https://api.github.com/repos/kommitters/stellar_sdk/issues/139'},
#      'comments': {'href': 'https://api.github.com/repos/kommitters/stellar_sdk/issues/139/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/kommitters/stellar_sdk/pulls/139/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/kommitters/stellar_sdk/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/kommitters/stellar_sdk/pulls/139/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/kommitters/stellar_sdk/statuses/30b33c120cd7c7093216da5e70d0ff27e4662bd8'}},
#     'author_association': 'MEMBER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'juanhurtado10',
#      'id': 1649973,
#      'node_id': 'MDQ6VXNlcjE2NDk5NzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1649973?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/juanhurtado10',
#      'html_url': 'https://github.com/juanhurtado10',
#      'followers_url': 'https://api.github.com/users/juanhurtado10/followers',
#      'following_url': 'https://api.github.com/users/juanhurtado10/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/juanhurtado10/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/juanhurtado10/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/juanhurtado10/subscriptions',
#      'organizations_url': 'https://api.github.com/users/juanhurtado10/orgs',
#      'repos_url': 'https://api.github.com/users/juanhurtado10/repos',
#      'events_url': 'https://api.github.com/users/juanhurtado10/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/juanhurtado10/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 3,
#     'additions': 210,
#     'deletions': 88,
#     'changed_files': 5}},
#   'public': True,
#   'created_at': '2022-04-15T15:24:05Z',
#   'org': {'id': 7662046,
#    'login': 'kommitters',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/kommitters',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7662046?'}},
#  {'id': '21308624265',
#   'type': 'CreateEvent',
#   'actor': {'id': 5866337,
#    'login': 'muratji',
#    'display_login': 'muratji',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/muratji',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5866337?'},
#   'repo': {'id': 482000566,
#    'name': 'muratji/plusralsight-woks',
#    'url': 'https://api.github.com/repos/muratji/plusralsight-woks'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-04-15T15:24:05Z'},
#  {'id': '21308624283',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 18085551,
#    'login': 'kxxt',
#    'display_login': 'kxxt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kxxt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18085551?'},
#   'repo': {'id': 127769231,
#    'name': 'DIYgod/RSSHub',
#    'url': 'https://api.github.com/repos/DIYgod/RSSHub'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/DIYgod/RSSHub/issues/9537',
#     'repository_url': 'https://api.github.com/repos/DIYgod/RSSHub',
#     'labels_url': 'https://api.github.com/repos/DIYgod/RSSHub/issues/9537/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/DIYgod/RSSHub/issues/9537/comments',
#     'events_url': 'https://api.github.com/repos/DIYgod/RSSHub/issues/9537/events',
#     'html_url': 'https://github.com/DIYgod/RSSHub/pull/9537',
#     'id': 1204673594,
#     'node_id': 'PR_kwDOB52aj842PsPH',
#     'number': 9537,
#     'title': 'feat(route): 山东大学（威海）新闻网',
#     'user': {'login': 'kxxt',
#      'id': 18085551,
#      'node_id': 'MDQ6VXNlcjE4MDg1NTUx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/18085551?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/kxxt',
#      'html_url': 'https://github.com/kxxt',
#      'followers_url': 'https://api.github.com/users/kxxt/followers',
#      'following_url': 'https://api.github.com/users/kxxt/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/kxxt/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/kxxt/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/kxxt/subscriptions',
#      'organizations_url': 'https://api.github.com/users/kxxt/orgs',
#      'repos_url': 'https://api.github.com/users/kxxt/repos',
#      'events_url': 'https://api.github.com/users/kxxt/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/kxxt/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 5,
#     'created_at': '2022-04-14T15:26:20Z',
#     'updated_at': '2022-04-15T15:24:05Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/DIYgod/RSSHub/pulls/9537',
#      'html_url': 'https://github.com/DIYgod/RSSHub/pull/9537',
#      'diff_url': 'https://github.com/DIYgod/RSSHub/pull/9537.diff',
#      'patch_url': 'https://github.com/DIYgod/RSSHub/pull/9537.patch',
#      'merged_at': None},
#     'body': "<!-- \r\n如有疑问，请参考 https://github.com/DIYgod/RSSHub/discussions/8002\r\nReference: https://github.com/DIYgod/RSSHub/discussions/8002\r\n-->\r\n\r\n## 该 PR 相关 Issue / Involved issue\r\n\r\n\r\n## 完整路由地址 / Example for the proposed route(s)\r\n\r\n<!--\r\n请在 `routes` 区域填写以 / 开头的完整路由地址，否则你的 PR 将会被无条件关闭。\r\n如果路由包含在文档中列出可以完全穷举的参数（例如分类），请依次全部列出。\r\n\r\nPlease include route starts with /, with all required and optional parameters. Fail to comply will result in your pull request being closed automatically.\r\n```route\r\n/some/route\r\n/some/other/route\r\n```\r\n如果你的 PR 与路由无关, 请在 route 区域 填写 `NOROUTE`，而不是直接删除 `routes` 区域。否则你的 PR 将会被无条件关闭。\r\nIf your changes are not related to route, please fill in `routes` with `NOROUTE`. Fail to comply will result in your PR being closed.\r\n-->\r\n\r\n```routes\r\n/sdu/wh/news/\r\n/sdu/wh/news/xyyw\r\n/sdu/wh/news/xsdt\r\n/sdu/wh/news/zhxw\r\n/sdu/wh/news/sdsd\r\n/sdu/wh/news/jjxy\r\n/sdu/wh/news/xyjx\r\n/sdu/wh/news/mjzc\r\n/sdu/wh/news/rdzt\r\n/sdu/wh/news/mtsj\r\n/sdu/wh/news/gjsy\r\n/sdu/wh/news/llxx\r\n```\r\n\r\n## 新 RSS 检查列表 / New RSS Script Checklist\r\n  \r\n- [x] 新的路由 New Route\r\n  - [x] 跟随 [v2 路由规范](https://docs.rsshub.app/joinus/script-standard.html) Follows [v2 Script Standard](https://docs.rsshub.app/en/joinus/script-standard.html)\r\n- [x] 文档说明 Documentation\r\n  - [x] 中文文档 CN\r\n  - [ ] 英文文档 EN\r\n- [x] 全文获取 fulltext\r\n  - [x] 使用缓存 Use Cache\r\n- [ ] 反爬/频率限制 anti-bot or rate limit?\r\n  - [ ] 如果有, 是否有对应的措施? If yes, do your code reflect this sign?\r\n- [x] [日期和时间](https://docs.rsshub.app/joinus/pub-date.html) [date and time](https://docs.rsshub.app/en/joinus/pub-date.html)\r\n  - [x] 可以解析 Parsed\r\n  - [ ] 时区调整 Correct TimeZone\r\n- [ ] 添加了新的包 New package added\r\n- [ ] `Puppeteer`\r\n\r\n## 说明 / Note\r\n\r\n我并不太清楚 `radar.js` 配置的是否正确，因为我在自己调试时没有成功。\r\n\r\n我在将以下配置复制到 RSS Radar 配置界面后，打开 https://xinwen.wh.sdu.edu.cn/ 之后， RSS Radar 并没有检测到 RSS.\r\n我没有找到原因，还请 reviewer 指点\r\n<details>\r\n<summary>生成的配置</summary>\r\n\r\n```js\r\n{\r\n  'sdu.edu.cn': {\r\n    _name: '山东大学',\r\n    'xinwen.wh': [\r\n      {\r\n        title: '校园要闻',\r\n        docs: 'https://docs.rsshub.app/university.html#shan-dong-da-xue-wei-hai-xin-wen-wang',\r\n        source: [ '/' ],\r\n        target: '/sduwh/news/xyyw'\r\n      },\r\n      {\r\n        title: '学生动态',\r\n        docs: 'https://docs.rsshub.app/university.html#shan-dong-da-xue-wei-hai-xin-wen-wang',\r\n        source: [ '/' ],\r\n        target: '/sduwh/news/xsdt'\r\n      },\r\n      {\r\n        title: '综合新闻',\r\n        docs: 'https://docs.rsshub.app/university.html#shan-dong-da-xue-wei-hai-xin-wen-wang',\r\n        source: [ '/' ],\r\n        target: '/sduwh/news/zhxw'\r\n      },\r\n      {\r\n        title: '山大视点',\r\n        docs: 'https://docs.rsshub.app/university.html#shan-dong-da-xue-wei-hai-xin-wen-wang',\r\n        source: [ '/' ],\r\n        target: '/sduwh/news/sdsd'\r\n      },\r\n      {\r\n        title: '菁菁校园',\r\n        docs: 'https://docs.rsshub.app/university.html#shan-dong-da-xue-wei-hai-xin-wen-wang',\r\n        source: [ '/' ],\r\n        target: '/sduwh/news/jjxy'\r\n      },\r\n      {\r\n        title: '校园简讯',\r\n        docs: 'https://docs.rsshub.app/university.html#shan-dong-da-xue-wei-hai-xin-wen-wang',\r\n        source: [ '/' ],\r\n        target: '/sduwh/news/xyjx'\r\n      },\r\n      {\r\n        title: '玛珈之窗',\r\n        docs: 'https://docs.rsshub.app/university.html#shan-dong-da-xue-wei-hai-xin-wen-wang',\r\n        source: [ '/' ],\r\n        target: '/sduwh/news/mjzc'\r\n      },\r\n      {\r\n        title: '热点专题',\r\n        docs: 'https://docs.rsshub.app/university.html#shan-dong-da-xue-wei-hai-xin-wen-wang',\r\n        source: [ '/' ],\r\n        target: '/sduwh/news/rdzt'\r\n      },\r\n      {\r\n        title: '媒体视角',\r\n        docs: 'https://docs.rsshub.app/university.html#shan-dong-da-xue-wei-hai-xin-wen-wang',\r\n        source: [ '/' ],\r\n        target: '/sduwh/news/mtsj'\r\n      },\r\n  ...
#     'reactions': {'url': 'https://api.github.com/repos/DIYgod/RSSHub/issues/9537/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/DIYgod/RSSHub/issues/9537/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/DIYgod/RSSHub/issues/comments/1100174121',
#     'html_url': 'https://github.com/DIYgod/RSSHub/pull/9537#issuecomment-1100174121',
#     'issue_url': 'https://api.github.com/repos/DIYgod/RSSHub/issues/9537',
#     'id': 1100174121,
#     'node_id': 'IC_kwDOB52aj85Bk1Mp',
#     'user': {'login': 'kxxt',
#      'id': 18085551,
#      'node_id': 'MDQ6VXNlcjE4MDg1NTUx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/18085551?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/kxxt',
#      'html_url': 'https://github.com/kxxt',
#      'followers_url': 'https://api.github.com/users/kxxt/followers',
#      'following_url': 'https://api.github.com/users/kxxt/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/kxxt/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/kxxt/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/kxxt/subscriptions',
#      'organizations_url': 'https://api.github.com/users/kxxt/orgs',
#      'repos_url': 'https://api.github.com/users/kxxt/repos',
#      'events_url': 'https://api.github.com/users/kxxt/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/kxxt/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2022-04-15T15:24:05Z',
#     'updated_at': '2022-04-15T15:24:05Z',
#     'author_association': 'NONE',
#     'body': 'I think everything works fine now. Maybe we can get it merged.\r\nThank you very much for your review. This is actually the first time that I get a true review ever since I joined GitHub.',
#     'reactions': {'url': 'https://api.github.com/repos/DIYgod/RSSHub/issues/comments/1100174121/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-04-15T15:24:05Z'},
#  {'id': '21308624274',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 346514288,
#    'name': 'birojnayak/cta',
#    'url': 'https://api.github.com/repos/birojnayak/cta'},
#   'payload': {'action': 'opened',
#    'number': 278,
#    'pull_request': {'url': 'https://api.github.com/repos/birojnayak/cta/pulls/278',
#     'id': 910920547,
#     'node_id': 'PR_kwDOFKdjcM42S4tj',
#     'html_url': 'https://github.com/birojnayak/cta/pull/278',
#     'diff_url': 'https://github.com/birojnayak/cta/pull/278.diff',
#     'patch_url': 'https://github.com/birojnayak/cta/pull/278.patch',
#     'issue_url': 'https://api.github.com/repos/birojnayak/cta/issues/278',
#     'number': 278,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump Codelyzer.Analysis.Model from 1.7.6-alpha-gf07df5afc7 to 2.3.45 in /src/CTA.Rules.Update',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [Codelyzer.Analysis.Model](https://github.com/aws/codelyzer) from 1.7.6-alpha-gf07df5afc7 to 2.3.45.\n<details>\n<summary>Commits</summary>\n<ul>\n<li>See full diff in <a href="https://github.com/aws/codelyzer/commits">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=Codelyzer.Analysis.Model&package-manager=nuget&previous-version=1.7.6-alpha-gf07df5afc7&new-version=2.3.45)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n\n\n</details>',
#     'created_at': '2022-04-15T15:24:05Z',
#     'updated_at': '2022-04-15T15:24:05Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/birojnayak/cta/pulls/278/commits',
#     'review_comments_url': 'https://api.github.com/repos/birojnayak/cta/pulls/278/comments',
#     'review_comment_url': 'https://api.github.com/repos/birojnayak/cta/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/birojnayak/cta/issues/278/comments',
#     'statuses_url': 'https://api.github.com/repos/birojnayak/cta/statuses/f52d69804637d63444f9d11ab55c63205227241c',
#     'head': {'label': 'birojnayak:dependabot/nuget/src/CTA.Rules.Update/Codelyzer.Analysis.Model-2.3.45',
#      'ref': 'dependabot/nuget/src/CTA.Rules.Update/Codelyzer.Analysis.Model-2.3.45',
#      'sha': 'f52d69804637d63444f9d11ab55c63205227241c',
#      'user': {'login': 'birojnayak',
#       'id': 49173255,
#       'node_id': 'MDQ6VXNlcjQ5MTczMjU1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/49173255?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/birojnayak',
#       'html_url': 'https://github.com/birojnayak',
#       'followers_url': 'https://api.github.com/users/birojnayak/followers',
#       'following_url': 'https://api.github.com/users/birojnayak/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/birojnayak/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/birojnayak/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/birojnayak/subscriptions',
#       'organizations_url': 'https://api.github.com/users/birojnayak/orgs',
#       'repos_url': 'https://api.github.com/users/birojnayak/repos',
#       'events_url': 'https://api.github.com/users/birojnayak/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/birojnayak/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 346514288,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNDY1MTQyODg=',
#       'name': 'cta',
#       'full_name': 'birojnayak/cta',
#       'private': False,
#       'owner': {'login': 'birojnayak',
#        'id': 49173255,
#        'node_id': 'MDQ6VXNlcjQ5MTczMjU1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/49173255?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/birojnayak',
#        'html_url': 'https://github.com/birojnayak',
#        'followers_url': 'https://api.github.com/users/birojnayak/followers',
#        'following_url': 'https://api.github.com/users/birojnayak/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/birojnayak/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/birojnayak/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/birojnayak/subscriptions',
#        'organizations_url': 'https://api.github.com/users/birojnayak/orgs',
#        'repos_url': 'https://api.github.com/users/birojnayak/repos',
#        'events_url': 'https://api.github.com/users/birojnayak/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/birojnayak/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/birojnayak/cta',
#       'description': 'Code translation assistance, a feature of Porting Assistant for .NET, helps users automate some aspects of their porting experience using a set of predefined rules and actions.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/birojnayak/cta',
#       'forks_url': 'https://api.github.com/repos/birojnayak/cta/forks',
#       'keys_url': 'https://api.github.com/repos/birojnayak/cta/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/birojnayak/cta/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/birojnayak/cta/teams',
#       'hooks_url': 'https://api.github.com/repos/birojnayak/cta/hooks',
#       'issue_events_url': 'https://api.github.com/repos/birojnayak/cta/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/birojnayak/cta/events',
#       'assignees_url': 'https://api.github.com/repos/birojnayak/cta/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/birojnayak/cta/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/birojnayak/cta/tags',
#       'blobs_url': 'https://api.github.com/repos/birojnayak/cta/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/birojnayak/cta/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/birojnayak/cta/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/birojnayak/cta/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/birojnayak/cta/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/birojnayak/cta/languages',
#       'stargazers_url': 'https://api.github.com/repos/birojnayak/cta/stargazers',
#       'contributors_url': 'https://api.github.com/repos/birojnayak/cta/contributors',
#       'subscribers_url': 'https://api.github.com/repos/birojnayak/cta/subscribers',
#       'subscription_url': 'https://api.github.com/repos/birojnayak/cta/subscription',
#       'commits_url': 'https://api.github.com/repos/birojnayak/cta/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/birojnayak/cta/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/birojnayak/cta/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/birojnayak/cta/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/birojnayak/cta/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/birojnayak/cta/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/birojnayak/cta/merges',
#       'archive_url': 'https://api.github.com/repos/birojnayak/cta/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/birojnayak/cta/downloads',
#       'issues_url': 'https://api.github.com/repos/birojnayak/cta/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/birojnayak/cta/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/birojnayak/cta/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/birojnayak/cta/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/birojnayak/cta/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/birojnayak/cta/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/birojnayak/cta/deployments',
#       'created_at': '2021-03-10T22:54:59Z',
#       'updated_at': '2021-09-23T17:16:29Z',
#       'pushed_at': '2022-04-15T15:24:05Z',
#       'git_url': 'git://github.com/birojnayak/cta.git',
#       'ssh_url': 'git@github.com:birojnayak/cta.git',
#       'clone_url': 'https://github.com/birojnayak/cta.git',
#       'svn_url': 'https://github.com/birojnayak/cta',
#       'homepage': '',
#       'size': 693,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C#',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 93,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 93,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'birojnayak:main',
#      'ref': 'main',
#      'sha': '3d64d5da2e5303bf308d28117a76fe8287518dfd',
#      'user': {'login': 'birojnayak',
#       'id': 49173255,
#       'node_id': 'MDQ6VXNlcjQ5MTczMjU1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/49173255?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/birojnayak',
#       'html_url': 'https://github.com/birojnayak',
#       'followers_url': 'https://api.github.com/users/birojnayak/followers',
#       'following_url': 'https://api.github.com/users/birojnayak/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/birojnayak/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/birojnayak/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/birojnayak/subscriptions',
#       'organizations_url': 'https://api.github.com/users/birojnayak/orgs',
#       'repos_url': 'https://api.github.com/users/birojnayak/repos',
#       'events_url': 'https://api.github.com/users/birojnayak/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/birojnayak/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 346514288,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNDY1MTQyODg=',
#       'name': 'cta',
#       'full_name': 'birojnayak/cta',
#       'private': False,
#       'owner': {'login': 'birojnayak',
#        'id': 49173255,
#        'node_id': 'MDQ6VXNlcjQ5MTczMjU1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/49173255?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/birojnayak',
#        'html_url': 'https://github.com/birojnayak',
#        'followers_url': 'https://api.github.com/users/birojnayak/followers',
#        'following_url': 'https://api.github.com/users/birojnayak/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/birojnayak/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/birojnayak/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/birojnayak/subscriptions',
#        'organizations_url': 'https://api.github.com/users/birojnayak/orgs',
#        'repos_url': 'https://api.github.com/users/birojnayak/repos',
#        'events_url': 'https://api.github.com/users/birojnayak/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/birojnayak/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/birojnayak/cta',
#       'description': 'Code translation assistance, a feature of Porting Assistant for .NET, helps users automate some aspects of their porting experience using a set of predefined rules and actions.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/birojnayak/cta',
#       'forks_url': 'https://api.github.com/repos/birojnayak/cta/forks',
#       'keys_url': 'https://api.github.com/repos/birojnayak/cta/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/birojnayak/cta/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/birojnayak/cta/teams',
#       'hooks_url': 'https://api.github.com/repos/birojnayak/cta/hooks',
#       'issue_events_url': 'https://api.github.com/repos/birojnayak/cta/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/birojnayak/cta/events',
#       'assignees_url': 'https://api.github.com/repos/birojnayak/cta/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/birojnayak/cta/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/birojnayak/cta/tags',
#       'blobs_url': 'https://api.github.com/repos/birojnayak/cta/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/birojnayak/cta/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/birojnayak/cta/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/birojnayak/cta/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/birojnayak/cta/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/birojnayak/cta/languages',
#       'stargazers_url': 'https://api.github.com/repos/birojnayak/cta/stargazers',
#       'contributors_url': 'https://api.github.com/repos/birojnayak/cta/contributors',
#       'subscribers_url': 'https://api.github.com/repos/birojnayak/cta/subscribers',
# ...
#       'merges_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/merges',
#       'archive_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/downloads',
#       'issues_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/deployments',
#       'created_at': '2022-04-04T20:48:51Z',
#       'updated_at': '2022-04-11T16:41:44Z',
#       'pushed_at': '2022-04-15T15:20:02Z',
#       'git_url': 'git://github.com/ethanchen7/Medium-Clone.git',
#       'ssh_url': 'git@github.com:ethanchen7/Medium-Clone.git',
#       'clone_url': 'https://github.com/ethanchen7/Medium-Clone.git',
#       'svn_url': 'https://github.com/ethanchen7/Medium-Clone',
#       'homepage': None,
#       'size': 1072,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 2,
#       'default_branch': 'main'}},
#     'base': {'label': 'ethanchen7:main',
#      'ref': 'main',
#      'sha': '7362878f861d6f4ca37489711af246c6459e2846',
#      'user': {'login': 'ethanchen7',
#       'id': 60331384,
#       'node_id': 'MDQ6VXNlcjYwMzMxMzg0',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/60331384?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ethanchen7',
#       'html_url': 'https://github.com/ethanchen7',
#       'followers_url': 'https://api.github.com/users/ethanchen7/followers',
#       'following_url': 'https://api.github.com/users/ethanchen7/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ethanchen7/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ethanchen7/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ethanchen7/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ethanchen7/orgs',
#       'repos_url': 'https://api.github.com/users/ethanchen7/repos',
#       'events_url': 'https://api.github.com/users/ethanchen7/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ethanchen7/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 477868332,
#       'node_id': 'R_kgDOHHuxLA',
#       'name': 'Medium-Clone',
#       'full_name': 'ethanchen7/Medium-Clone',
#       'private': False,
#       'owner': {'login': 'ethanchen7',
#        'id': 60331384,
#        'node_id': 'MDQ6VXNlcjYwMzMxMzg0',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/60331384?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ethanchen7',
#        'html_url': 'https://github.com/ethanchen7',
#        'followers_url': 'https://api.github.com/users/ethanchen7/followers',
#        'following_url': 'https://api.github.com/users/ethanchen7/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ethanchen7/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ethanchen7/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ethanchen7/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ethanchen7/orgs',
#        'repos_url': 'https://api.github.com/users/ethanchen7/repos',
#        'events_url': 'https://api.github.com/users/ethanchen7/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ethanchen7/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/ethanchen7/Medium-Clone',
#       'description': 'Express/JS Clone Project - Group 3',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ethanchen7/Medium-Clone',
#       'forks_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/forks',
#       'keys_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/teams',
#       'hooks_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/events',
#       'assignees_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/tags',
#       'blobs_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/languages',
#       'stargazers_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/subscription',
#       'commits_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/merges',
#       'archive_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/downloads',
#       'issues_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ethanchen7/Medium-Clone/deployments',
#       'created_at': '2022-04-04T20:48:51Z',
#       'updated_at': '2022-04-11T16:41:44Z',
#       'pushed_at': '2022-04-15T15:20:02Z',
#       'git_url': 'git://github.com/ethanchen7/Medium-Clone.git',
#       'ssh_url': 'git@github.com:ethanchen7/Medium-Clone.git',
#       'clone_url': 'https://github.com/ethanchen7/Medium-Clone.git',
#       'svn_url': 'https://github.com/ethanchen7/Medium-Clone',
#       'homepage': None,
#       'size': 1072,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 2,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/ethanchen7/Medium-Clone/pulls/44'},
#      'html': {'href': 'https://github.com/ethanchen7/Medium-Clone/pull/44'},
#      'issue': {'href': 'https://api.github.com/repos/ethanchen7/Medium-Clone/issues/44'},
#      'comments': {'href': 'https://api.github.com/repos/ethanchen7/Medium-Clone/issues/44/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/ethanchen7/Medium-Clone/pulls/44/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/ethanchen7/Medium-Clone/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/ethanchen7/Medium-Clone/pulls/44/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/ethanchen7/Medium-Clone/statuses/2a485ea6319ac70215940033a28377a32a8a2f41'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 7,
#     'additions': 309,
#     'deletions': 126,
#     'changed_files': 8}},
#   'public': True,
#   'created_at': '2022-04-15T15:24:05Z'},
#  {'id': '21308624192',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 85187633,
#    'login': 'snasovich',
#    'display_login': 'snasovich',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/snasovich',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/85187633?'},
#   'repo': {'id': 26337322,
#    'name': 'rancher/rancher',
#    'url': 'https://api.github.com/repos/rancher/rancher'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/rancher/rancher/issues/36824',
#     'repository_url': 'https://api.github.com/repos/rancher/rancher',
#     'labels_url': 'https://api.github.com/repos/rancher/rancher/issues/36824/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/rancher/rancher/issues/36824/comments',
#     'events_url': 'https://api.github.com/repos/rancher/rancher/issues/36824/events',
#     'html_url': 'https://github.com/rancher/rancher/pull/36824',
#     'id': 1164028064,
#     'node_id': 'PR_kwDOAZHgKs40LUZT',
#     'number': 36824,
#     'title': 'Add machine PlanApplied condition to provide feedback on failed plans and change logic to allow unavailable nodes to be updated immediately',
#     'user': {'login': 'Oats87',
#      'id': 30601846,
#      'node_id': 'MDQ6VXNlcjMwNjAxODQ2',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/30601846?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Oats87',
#      'html_url': 'https://github.com/Oats87',
#      'followers_url': 'https://api.github.com/users/Oats87/followers',
#      'following_url': 'https://api.github.com/users/Oats87/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Oats87/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Oats87/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Oats87/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Oats87/orgs',
#      'repos_url': 'https://api.github.com/users/Oats87/repos',
#      'events_url': 'https://api.github.com/users/Oats87/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Oats87/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2022-03-09T14:41:46Z',
#     'updated_at': '2022-04-15T15:24:05Z',
#     'closed_at': '2022-04-15T03:51:39Z',
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/rancher/rancher/pulls/36824',
#      'html_url': 'https://github.com/rancher/rancher/pull/36824',
#      'diff_url': 'https://github.com/rancher/rancher/pull/36824.diff',
#      'patch_url': 'https://github.com/rancher/rancher/pull/36824.patch',
#      'merged_at': '2022-04-15T03:51:39Z'},
#     'body': 'https://github.com/rancher/rancher/issues/36822\r\n\r\nalso, \r\n\r\nhttps://github.com/rancher/rancher/issues/37190',
#     'reactions': {'url': 'https://api.github.com/repos/rancher/rancher/issues/36824/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/rancher/rancher/issues/36824/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/rancher/rancher/issues/comments/1100174116',
#     'html_url': 'https://github.com/rancher/rancher/pull/36824#issuecomment-1100174116',
#     'issue_url': 'https://api.github.com/repos/rancher/rancher/issues/36824',
#     'id': 1100174116,
#     'node_id': 'IC_kwDOAZHgKs5Bk1Mk',
#     'user': {'login': 'snasovich',
#      'id': 85187633,
#      'node_id': 'MDQ6VXNlcjg1MTg3NjMz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/85187633?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/snasovich',
#      'html_url': 'https://github.com/snasovich',
#      'followers_url': 'https://api.github.com/users/snasovich/followers',
#      'following_url': 'https://api.github.com/users/snasovich/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/snasovich/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/snasovich/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/snasovich/subscriptions',
#      'organizations_url': 'https://api.github.com/users/snasovich/orgs',
#      'repos_url': 'https://api.github.com/users/snasovich/repos',
#      'events_url': 'https://api.github.com/users/snasovich/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/snasovich/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2022-04-15T15:24:04Z',
#     'updated_at': '2022-04-15T15:24:04Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': 'This should also fix https://github.com/rancher/rancher/issues/37364 (already mentioned on the issue, but adding for better linking).',
#     'reactions': {'url': 'https://api.github.com/repos/rancher/rancher/issues/comments/1100174116/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-04-15T15:24:05Z',
#   'org': {'id': 9343010,
#    'login': 'rancher',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/rancher',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9343010?'}}]

# %% [markdown]
# # Gotta Catch 'Em All! Using the Pokemon API
#
# https://pokeapi.co/
#
# Nice place to start because there's no login details or credentials to fuss with
#
# For now, just want to explore grabbing the Types of different Pokemon.
#
# Useful documentation links:
# - Pokemon endpoint: https://pokeapi.co/docs/v2#pokemon
#     - `https://pokeapi.co/api/v2/pokemon/{id or name}/`
# - Type endpoint: https://pokeapi.co/docs/v2#types
#     - `https://pokeapi.co/api/v2/type/{id or name}/`

# %% [markdown]
# ### Start by exploring the response from the Pokemon endpoint
#
# Going to start with Charmander, pokemon #4, cause he's one of my favorites
#
# <img src="https://i.pinimg.com/originals/e7/0e/d0/e70ed0b54f9230c56c2e3bd2958d68a4.jpg" alt="adorable charmander found via pinterest" width=150>
#
# [Image Source](https://www.pinterest.com/pin/419045940312305352/)

# %%
# First, what endpoint url are we using?
base_poke_url = "https://pokeapi.co/api/v2/pokemon/"

# %%
# How does that need to adapt for charmander?
char_url = f"{base_poke_url}4"

# %%
char_url
# Out:
# 'https://pokeapi.co/api/v2/pokemon/4'

# %%
# Check the status code, will this work?
requests.get(char_url).status_code
# Out:
# 200

# %%
# Now let's actually get the response
char_resp = requests.get(char_url).json()

# %%
type(char_resp)
# Out:
# dict

# %%
# Let's check out some details about the response
char_resp.keys()
# Out:
# dict_keys(['abilities', 'base_experience', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'past_types', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
char_resp['id']
# Out:
# 4

# %%
char_resp['name']
# Out:
# 'charmander'

# %%
char_resp['types']
# Out:
# [{'slot': 1,
#   'type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}}]

# %%
bulb_resp = requests.get(f'{base_poke_url}1').json()

# %%
bulb_resp['types'][1]
# Out:
# {'slot': 2,
#  'type': {'name': 'poison', 'url': 'https://pokeapi.co/api/v2/type/4/'}}

# %% [markdown]
# #### Challenge!
#
# Let's write a function that, given a response from this API's pokemon endpoint, returns a list of the ID, name, primary type and secondary type for that pokemon.

# %%
def get_pokemon_details(poke_resp):
    '''
    inputs:
    poke_resp - expects json/dict
    
    outputs: 
    list of id, pokemon name, names of the primary and secondary types 
    '''
#     poke_list = []
    
#     for key, value in poke_resp.items():
#         if key == 'id':
#             poke_list.append(value)
#         elif key == 'name':
#             poke_list.append(value)
    poke_id = poke_resp['id']
    poke_name = poke_resp['name']
    
#     types_list = []
#     for p_type in poke_resp['types']:
#         types_list.append(p_type['type']['name'])
    p_types = poke_resp['types']
    
    primary_type = p_types[0]['type']['name']
    
    if len(p_types) = 1:
        secondary_type = None
    else:
        secondary_type = p_types[1]['type']['name']
    
    
    return [poke_id, poke_name, primary_type, secondary_type]

# %%
get_pokemon_details(char_resp)
# Out:
# [4, 'charmander', 'fire']

# %%
# Let's test our function on the 3 original starter pokemon
original_starter_ids = list(range(1,10, 3))
print(original_starter_ids)
# Out:
# [1, 4, 7]

# %%
for poke_id in original_starter_ids:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    print(details)
# Out:
# [1, 'bulbasaur', 'grass', 'poison']
# [4, 'charmander', 'fire']
# [7, 'squirtle', 'water']

# %% [markdown]
# ### Moving to Pandas
#
# Let's get all of these details for all of the original 151 pokemon! And save them to a Pandas dataframe.

# %%
# Need to import pandas
import pandas as pd

# %%
# Let's go ahead and define what our columns will be
col_names = ['id', 'name', 'primary_type', 'secondary_type']

# %%
col_names
# Out:
# ['id', 'name', 'primary_type', 'secondary_type']

# %%
# Define a list of our 151 pokemon ids
original_151 = list(range(1,152))

# %% [markdown]
# So we're going to make 151 requests... don't want to overload the API endpoint! So let's use the time library to space out our requests.

# %%
import time

# %%
# Easiest way to do this will be to have a list of lists, then concat them all

# Define a blank list to capture all the pokemon details
row_list = []

# And then loop over our pokemon ids!
for poke_id in original_151:
    url = f"{base_poke_url}{poke_id}/"
    resp = requests.get(url).json()
    details = get_pokemon_details(resp)
    row_list.append(details)
    time.sleep(1)
    
# Then, concat everything into one df
# Reference: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html
# poke_df = pd.concat([pd.DataFrame([i], columns = col_names) for i in row_list], ignore_index=True)

# %%
# for row in row_list:
#     if len(row) == 3:
#         row.append(None)

# %%
row_list
# Out:
# [[1, 'bulbasaur', 'grass', 'poison'],
#  [2, 'ivysaur', 'grass', 'poison'],
#  [3, 'venusaur', 'grass', 'poison'],
#  [4, 'charmander', 'fire', None],
#  [5, 'charmeleon', 'fire', None],
#  [6, 'charizard', 'fire', 'flying'],
#  [7, 'squirtle', 'water', None],
#  [8, 'wartortle', 'water', None],
#  [9, 'blastoise', 'water', None],
#  [10, 'caterpie', 'bug', None],
#  [11, 'metapod', 'bug', None],
#  [12, 'butterfree', 'bug', 'flying'],
#  [13, 'weedle', 'bug', 'poison'],
#  [14, 'kakuna', 'bug', 'poison'],
#  [15, 'beedrill', 'bug', 'poison'],
#  [16, 'pidgey', 'normal', 'flying'],
#  [17, 'pidgeotto', 'normal', 'flying'],
#  [18, 'pidgeot', 'normal', 'flying'],
#  [19, 'rattata', 'normal', None],
#  [20, 'raticate', 'normal', None],
#  [21, 'spearow', 'normal', 'flying'],
#  [22, 'fearow', 'normal', 'flying'],
#  [23, 'ekans', 'poison', None],
#  [24, 'arbok', 'poison', None],
#  [25, 'pikachu', 'electric', None],
#  [26, 'raichu', 'electric', None],
#  [27, 'sandshrew', 'ground', None],
#  [28, 'sandslash', 'ground', None],
#  [29, 'nidoran-f', 'poison', None],
#  [30, 'nidorina', 'poison', None],
#  [31, 'nidoqueen', 'poison', 'ground'],
#  [32, 'nidoran-m', 'poison', None],
#  [33, 'nidorino', 'poison', None],
#  [34, 'nidoking', 'poison', 'ground'],
#  [35, 'clefairy', 'fairy', None],
#  [36, 'clefable', 'fairy', None],
#  [37, 'vulpix', 'fire', None],
#  [38, 'ninetales', 'fire', None],
#  [39, 'jigglypuff', 'normal', 'fairy'],
#  [40, 'wigglytuff', 'normal', 'fairy'],
#  [41, 'zubat', 'poison', 'flying'],
#  [42, 'golbat', 'poison', 'flying'],
#  [43, 'oddish', 'grass', 'poison'],
#  [44, 'gloom', 'grass', 'poison'],
#  [45, 'vileplume', 'grass', 'poison'],
#  [46, 'paras', 'bug', 'grass'],
#  [47, 'parasect', 'bug', 'grass'],
#  [48, 'venonat', 'bug', 'poison'],
#  [49, 'venomoth', 'bug', 'poison'],
#  [50, 'diglett', 'ground', None],
#  [51, 'dugtrio', 'ground', None],
#  [52, 'meowth', 'normal', None],
#  [53, 'persian', 'normal', None],
#  [54, 'psyduck', 'water', None],
#  [55, 'golduck', 'water', None],
#  [56, 'mankey', 'fighting', None],
#  [57, 'primeape', 'fighting', None],
#  [58, 'growlithe', 'fire', None],
#  [59, 'arcanine', 'fire', None],
#  [60, 'poliwag', 'water', None],
#  [61, 'poliwhirl', 'water', None],
#  [62, 'poliwrath', 'water', 'fighting'],
#  [63, 'abra', 'psychic', None],
#  [64, 'kadabra', 'psychic', None],
#  [65, 'alakazam', 'psychic', None],
#  [66, 'machop', 'fighting', None],
#  [67, 'machoke', 'fighting', None],
#  [68, 'machamp', 'fighting', None],
#  [69, 'bellsprout', 'grass', 'poison'],
#  [70, 'weepinbell', 'grass', 'poison'],
#  [71, 'victreebel', 'grass', 'poison'],
#  [72, 'tentacool', 'water', 'poison'],
#  [73, 'tentacruel', 'water', 'poison'],
#  [74, 'geodude', 'rock', 'ground'],
#  [75, 'graveler', 'rock', 'ground'],
#  [76, 'golem', 'rock', 'ground'],
#  [77, 'ponyta', 'fire', None],
#  [78, 'rapidash', 'fire', None],
#  [79, 'slowpoke', 'water', 'psychic'],
#  [80, 'slowbro', 'water', 'psychic'],
#  [81, 'magnemite', 'electric', 'steel'],
#  [82, 'magneton', 'electric', 'steel'],
#  [83, 'farfetchd', 'normal', 'flying'],
#  [84, 'doduo', 'normal', 'flying'],
#  [85, 'dodrio', 'normal', 'flying'],
#  [86, 'seel', 'water', None],
#  [87, 'dewgong', 'water', 'ice'],
#  [88, 'grimer', 'poison', None],
#  [89, 'muk', 'poison', None],
#  [90, 'shellder', 'water', None],
#  [91, 'cloyster', 'water', 'ice'],
#  [92, 'gastly', 'ghost', 'poison'],
#  [93, 'haunter', 'ghost', 'poison'],
#  [94, 'gengar', 'ghost', 'poison'],
#  [95, 'onix', 'rock', 'ground'],
#  [96, 'drowzee', 'psychic', None],
#  [97, 'hypno', 'psychic', None],
#  [98, 'krabby', 'water', None],
#  [99, 'kingler', 'water', None],
#  [100, 'voltorb', 'electric', None],
#  [101, 'electrode', 'electric', None],
#  [102, 'exeggcute', 'grass', 'psychic'],
#  [103, 'exeggutor', 'grass', 'psychic'],
#  [104, 'cubone', 'ground', None],
#  [105, 'marowak', 'ground', None],
#  [106, 'hitmonlee', 'fighting', None],
#  [107, 'hitmonchan', 'fighting', None],
#  [108, 'lickitung', 'normal', None],
#  [109, 'koffing', 'poison', None],
#  [110, 'weezing', 'poison', None],
#  [111, 'rhyhorn', 'ground', 'rock'],
#  [112, 'rhydon', 'ground', 'rock'],
#  [113, 'chansey', 'normal', None],
#  [114, 'tangela', 'grass', None],
#  [115, 'kangaskhan', 'normal', None],
#  [116, 'horsea', 'water', None],
#  [117, 'seadra', 'water', None],
#  [118, 'goldeen', 'water', None],
#  [119, 'seaking', 'water', None],
#  [120, 'staryu', 'water', None],
#  [121, 'starmie', 'water', 'psychic'],
#  [122, 'mr-mime', 'psychic', 'fairy'],
#  [123, 'scyther', 'bug', 'flying'],
#  [124, 'jynx', 'ice', 'psychic'],
#  [125, 'electabuzz', 'electric', None],
#  [126, 'magmar', 'fire', None],
#  [127, 'pinsir', 'bug', None],
#  [128, 'tauros', 'normal', None],
#  [129, 'magikarp', 'water', None],
#  [130, 'gyarados', 'water', 'flying'],
#  [131, 'lapras', 'water', 'ice'],
#  [132, 'ditto', 'normal', None],
#  [133, 'eevee', 'normal', None],
#  [134, 'vaporeon', 'water', None],
#  [135, 'jolteon', 'electric', None],
#  [136, 'flareon', 'fire', None],
#  [137, 'porygon', 'normal', None],
#  [138, 'omanyte', 'rock', 'water'],
#  [139, 'omastar', 'rock', 'water'],
#  [140, 'kabuto', 'rock', 'water'],
#  [141, 'kabutops', 'rock', 'water'],
#  [142, 'aerodactyl', 'rock', 'flying'],
#  [143, 'snorlax', 'normal', None],
#  [144, 'articuno', 'ice', 'flying'],
#  [145, 'zapdos', 'electric', 'flying'],
#  [146, 'moltres', 'fire', 'flying'],
#  [147, 'dratini', 'dragon', None],
#  [148, 'dragonair', 'dragon', None],
#  [149, 'dragonite', 'dragon', 'flying'],
#  [150, 'mewtwo', 'psychic', None],
#  [151, 'mew', 'psychic', None]]

# %%
poke_df = pd.concat([pd.DataFrame([row], columns = col_names) for row in row_list], ignore_index=True)

# %%
poke_df
# Out:
#       id        name primary_type secondary_type
# 0      1   bulbasaur        grass         poison
# 1      2     ivysaur        grass         poison
# 2      3    venusaur        grass         poison
# 3      4  charmander         fire           None
# 4      5  charmeleon         fire           None
# ..   ...         ...          ...            ...
# 146  147     dratini       dragon           None
# 147  148   dragonair       dragon           None
# 148  149   dragonite       dragon         flying
# 149  150      mewtwo      psychic           None
# 150  151         mew      psychic           None
#
# [151 rows x 4 columns]

# %%
# visualize it!
import matplotlib.pyplot as plt

primary_type_count = poke_df.groupby('primary_type').count()['id'].sort_values(ascending=False)

plt.figure(figsize=(10,8))
plt.bar(primary_type_count.index, primary_type_count)

plt.title("Counts of Pokemon Primary Types")
plt.ylabel("Number of Pokemon")
plt.xlabel("Primary Type")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ![monty python gif - and now for something completely different, from giphy](https://media.giphy.com/media/xznyPebL28X5u/giphy.gif)

# %% [markdown]
# # Movie Time!
#
# Let's practice with an API that actually requires some authorization, in the form of an API Key!
#
# https://www.themoviedb.org/documentation/api

# %% [markdown]
# # **NEVER EVER PUT YOUR API KEY ON GITHUB**
#
# Either create a json file with API keys in a different directory, or create a python file with the key saved as a variable that you can call. (There are even more options than that, but these are two easily-accessible ones)

# %%
# Option 1: use a json file saved to some other folder outside your Git repo
# You can make a secrets folder on your ~ directory!
# In a new terminal window, create a file called api.json and save the path to that file

# Need to import json to do this
import json

# Quick helper function to open the json
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# Using the function to open and load all keys in that file 
api_keys = get_keys("/Users/lberlin/secrets/api.json")

# Setting the first (and only) value as a variable
tmdb_key_1 = api_keys['tmdb_key']

# %%
# Option 2: use a python file that's been added to your .gitignore

# In a new terminal window, create a file called keys.py in this repo
# Save the api key as tmdb_api_key = "[key]"

from keys import tmdb_key

tmdb_key_2 = tmdb_key

# Then let's edit our .gitignore file together

# %% [markdown]
# Just as important! You may want to call the variable you've set to check that the API key is rendering correctly - but **be sure to clear the output of that cell** or else the output will show your key! And then if you push to GitHub it'll push that output to the internet which defeats the whole point of saving your key elsewhere!

# %% [markdown]
# ### And now, accessing movie data
#
# Documentation: https://developers.themoviedb.org/3

# %%
# Default URL given as an example... let's see what it is!
test_url = f"https://api.themoviedb.org/3/movie/550?api_key={tmdb_key_1}"

# %%
requests.get(test_url).status_code
# Out:
# 200

# %%
test_resp = requests.get(test_url).json()

# %%
test_resp.keys()
# Out:
# dict_keys(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id', 'imdb_id', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'video', 'vote_average', 'vote_count'])

# %%
# Find similar movies to the previous id
fight_club_id = 550
similar_url = f"https://api.themoviedb.org/3/movie/{fight_club_id}/similar?api_key={tmdb_key_1}"
similar_resp = requests.get(similar_url).json()

# %%
similar_resp.keys()
# Out:
# dict_keys(['page', 'results', 'total_pages', 'total_results'])

# %%
# How many similar movies did it find?
similar_resp['total_results']
# Out:
# 10000

# %%
# but is that the length of these results?
len(similar_resp['results'])
# Out:
# 20

# %%
# what's in here?
for res in similar_resp['results']:
    print(res['title'])
# Out:
# Cry Macho
# American Badger
# The Colony
# Black Crab
# Outlaws
# Don't Kill Me
# Battle: Freestyle
# I, Robot
# Barry Lyndon
# Night Watch
# Doctor Dolittle
# The Treasure of the Sierra Madre
# Girl, Interrupted
# Emma
# The Number 23
# The Machinist
# The Story of O
# Sense and Sensibility
# Flash Gordon
# Girl with a Pearl Earring

# %% [markdown]
# ## Level Up: Another Way to Deal with APIs
#
# Check out [Postman](https://www.getpostman.com/).

# %% [markdown]
# ## Extra Credit: Further Practice
#
# There are many ways to access data through APIs! [Sodapy](https://github.com/xmunoz/sodapy) is the Python client for the Socrata Open Data API.

# %%
# Install before running 
# !pip install sodapy

# %% [markdown]
# #### Tokenize yourself!
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
# Scroll down and click to sign up for an app token! No credit cards required!

# %%
token = '' # paste your token here 

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", token)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("fhrw-4uyv", incident_zip = '11004', limit=1000)

# %%
type(results)

# %%
len(results)

# %%
results[0]

# %%
df_soda = pd.DataFrame(results)

print(len(df_soda))
print(df_soda.columns)
df_soda.head()

# %% [markdown]
# ## Even Further Practice
#
# https://github.com/toddmotto/public-apis
#
# Find a buddy, find a free api, get a key, and do a GET. Try to transform the response into a dataframe.
